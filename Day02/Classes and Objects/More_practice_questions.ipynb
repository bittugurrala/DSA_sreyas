# %% [markdown]
# # OOPS Practice Problems -Beginners
#
# ---
#
# ## 1. Student Management System
#
# ### Problem:
#
# Create a `Student` class with:
#
# * Name
# * Roll number
# * Marks
#
# ### Methods:
#
# * Display student details
# * Check pass or fail
#
# ---
#
# ## 2. Employee Salary System
#
# ### Problem:
#
# Create an `Employee` class with:
#
# * Name
# * Employee ID
# * Basic salary
#
# ### Methods:
#
# * Calculate total salary (add bonus)
# * Display employee details
#
# ---
#
# ## 3. Mobile Phone Class
#
# ### Problem:
#
# Create a `Mobile` class with:
#
# * Brand
# * Model
# * Price
#
# ### Methods:
#
# * Apply discount
# * Display mobile details
#
# ---
#
# ## 4. Library Book System
#
# ### Problem:
#
# Create a `Book` class with:
#
# * Title
# * Author
# * Available copies
#
# ### Methods:
#
# * Borrow book
# * Return book
# * Check availability
#
# ---
#
# ## 5. Car Speed Control System
#
# ### Problem:
#
# Create a `Car` class with:
#
# * Brand
# * Speed
#
# ### Methods:
#
# * Accelerate
# * Brake
# * Display current speed
#
# ---
#
# ## 6. Bank Account (Extended Practice)
#
# ### Problem:
#
# Enhance your bank account:
#
# * Add minimum balance rule
# * Add daily withdrawal limit
# * Add transaction count
#
# ---
#
# ## 7. ATM Machine Simulator
#
# ### Problem:
#
# Create an `ATM` class with:
#
# * User name
# * PIN
# * Balance
#
# ### Methods:
#
# * Check balance
# * Deposit
# * Withdraw
# * Change PIN
#
# ---
#
# ## 8. Online Shopping Cart
#
# ### Problem:
#
# Create a `ShoppingCart` class with:
#
# * Product name
# * Price
# * Quantity
#
# ### Methods:
#
# * Add product
# * Remove product
# * Display total bill
#
# ---
#
# ## 9. Movie Ticket Booking System
#
# ### Problem:
#
# Create a `MovieTicket` class with:
#
# * Movie name
# * Seat count
# * Ticket price
#
# ### Methods:
#
# * Book tickets
# * Cancel tickets
# * Display bill
#
# ---
#
# ## 10. Attendance System
#
# ### Problem:
#
# Create an `Attendance` class with:
#
# * Student name
# * Total days
# * Present days
#
# ### Methods:
#
# * Mark attendance
# * Calculate attendance percentage
#
# ---
#
# # Medium-Level Practice (After 1 Week)
#
# ---
#
# ## 11. Railway Reservation System
#
# * Train number
# * Passenger name
# * Seat availability
# * Booking & Cancellation
#
# ---
#
# ## 12. Hospital Management System
#
# * Patient name
# * Doctor name
# * Fees
# * Appointment booking
#
# ---
#
# ## 13. Inventory Management System
#
# * Product name
# * Stock
# * Sales & Purchase
#
# ---
#
# ## 14. College Fee Management
#
# * Student name
# * Total fee
# * Paid amount
# * Due calculation
#
# ---
#
# ## 15. Online Examination System
#
# * Student name
# * Subject
# * Marks
# * Result calculation
#
# ---
